# %% [markdown]
# <h2>A Data Driven Approach to Predicting Chemical Reaction Kinetics: Database Expansion</h2>
# <br>
# Maneet Goyal<sup>1</sup>, Keren Zhang<sup>2</sup>
# <br>
# <i><sup>1</sup>School of Civil and Environmental Engineering, <sup>2</sup>School of Chemical and Biomolecular Engineering, Georgia Institute of Technology, Atlanta, GA</i>
# <hr>

# %%
# Displaying Package Skeleton
from IPython.display import display, Image
display(Image("Report/PackageSkeleton.png"))

# %%
# Performing Expansion Routine
import expansion_utils as eu

# Here, we first try the old Species.xlsx (the one without any new PubChem Entries)
eu.Extender.expand_data(
    new_species_xlsx = "PreliminaryOutput/DemoGenerated/ExpansionSample/OldSpecies.xlsx", 
    output_hdf5 = "PreliminaryOutput/DemoGenerated/ExpansionSample/DataDF.h5", 
    species_df_key = "Species", 
    rxn_df_key = "Reactions", 
    elements_csv = "FeatureLibrary/elements.csv", 
    bonds_csv = "FeatureLibrary/bonds.csv", 
    new_xlsx_path = "PreliminaryOutput/DemoGenerated/ExpansionSample/TrainingDataOldSpecies.xlsx")
# Out:
# --Status--
# --0 New Species Added--
# No new changes were made as there were no new species to add.

# %%
# Here, we first try the new Species.xlsx (the one with 10 new PubChem Entries)
eu.Extender.expand_data(
    new_species_xlsx = "PreliminaryOutput/DemoGenerated/ExpansionSample/NewSpecies.xlsx", 
    output_hdf5 = "PreliminaryOutput/DemoGenerated/ExpansionSample/DataDF.h5", 
    species_df_key = "Species", 
    rxn_df_key = "Reactions", 
    elements_csv = "FeatureLibrary/elements.csv", 
    bonds_csv = "FeatureLibrary/bonds.csv", 
    new_xlsx_path = "PreliminaryOutput/DemoGenerated/ExpansionSample/TrainingDataNewSpecies.xlsx")
# Out:
# --Data fetched for CID 5460557--
# --Data fetched for CID 807--
# --Data fetched for CID 123247--
# --Data fetched for CID 24524--
# --Data fetched for CID 6212--
# --Data fetched for CID 137553--
# --Data fetched for CID 140487--
# --Data fetched for CID 6338--
# --Data fetched for CID 137452--
# --Data fetched for CID 996--
# --Status--
# --10 New Species Added--
# c:\users\maneet\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['Species', 'BondsInfo', 'FeatureVector']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# c:\users\maneet\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# ...
